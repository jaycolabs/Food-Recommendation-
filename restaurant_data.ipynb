# %% [markdown]
# # Cleaning Data For Food Recommendation
#
# # Joel Parker
#
# # Data from: https://www.mavenanalytics.io/data-playground?page=2&pageSize=5 (Restaurant Ratings)

# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np

# %%
rest = pd.read_csv('restaurants.csv')
rest
# Out:
#      Restaurant_ID                        Name             City  \
# 0           132560          Puesto de Gorditas  Ciudad Victoria
# 1           132561                  Cafe Ambar  Ciudad Victoria
# 2           132564                    Church's  Ciudad Victoria
# 3           132572                Cafe Chaires  San Luis Potosi
# 4           132583            McDonalds Centro       Cuernavaca
# ..             ...                         ...              ...
# 125         135088           Cafeteria Cenidet       Cuernavaca
# 126         135104                        Vips  Ciudad Victoria
# 127         135106  El Rincón De San Francisco  San Luis Potosi
# 128         135108                  Potzocalli  San Luis Potosi
# 129         135109                   Paniroles       Cuernavaca
#
#                State Country  Zip_Code   Latitude   Longitude Alcohol_Service  \
# 0         Tamaulipas  Mexico       NaN  23.752304  -99.166913            None
# 1         Tamaulipas  Mexico       NaN  23.726819  -99.126506            None
# 2         Tamaulipas  Mexico       NaN  23.730925  -99.145185            None
# 3    San Luis Potosi  Mexico       NaN  22.141647 -100.992712            None
# 4            Morelos  Mexico   62000.0  18.922290  -99.234332            None
# ..               ...     ...       ...        ...         ...             ...
# 125          Morelos  Mexico       NaN  18.876011  -99.219890            None
# 126       Tamaulipas  Mexico       NaN  23.752982  -99.168434        Full Bar
# 127  San Luis Potosi  Mexico   78000.0  22.149709 -100.976093     Wine & Beer
# 128  San Luis Potosi  Mexico       NaN  22.136253 -100.933585            None
# 129          Morelos  Mexico       NaN  18.921785  -99.235350     Wine & Beer
#
#     Smoking_Allowed   Price Franchise    Area Parking
# 0               Yes     Low        No    Open  Public
# 1                No     Low        No  Closed    None
# 2                No     Low        No  Closed    None
# 3                No     Low        No  Closed     Yes
# 4                No     Low       Yes  Closed    None
# ..              ...     ...       ...     ...     ...
# 125              No     Low        No  Closed  Public
# 126              No  Medium       Yes  Closed     Yes
# 127        Bar Only  Medium        No    Open    None
# 128              No     Low        No  Closed    None
# 129              No  Medium        No  Closed    None
#
# [130 rows x 14 columns]

# %%
rest_cuisines = pd.read_csv('restaurant_cuisines.csv')
rest_cuisines
# Out:
#      Restaurant_ID    Cuisine
# 0           132560   Regional
# 1           132572  Cafeteria
# 2           132583   American
# 3           132584    Mexican
# 4           132594    Mexican
# ..             ...        ...
# 107         135086  Fast Food
# 108         135088  Cafeteria
# 109         135104    Mexican
# 110         135106    Mexican
# 111         135109    Italian
#
# [112 rows x 2 columns]

# %% [markdown]
# # Merge Dataframes

# %%
restaurant_df = pd.merge(rest, rest_cuisines, on='Restaurant_ID')

# %%
restaurant_df
# Out:
#      Restaurant_ID                                Name             City  \
# 0           132560                  Puesto de Gorditas  Ciudad Victoria
# 1           132572                        Cafe Chaires  San Luis Potosi
# 2           132583                    McDonalds Centro       Cuernavaca
# 3           132584                  Gorditas Doña Tota  Ciudad Victoria
# 4           132594  Tacos De Barbacoa Enfrente Del Tec  Ciudad Victoria
# ..             ...                                 ...              ...
# 107         135086         McDonalds Parque Tangamanga  San Luis Potosi
# 108         135088                   Cafeteria Cenidet       Cuernavaca
# 109         135104                                Vips  Ciudad Victoria
# 110         135106          El Rincón De San Francisco  San Luis Potosi
# 111         135109                           Paniroles       Cuernavaca
#
#                State Country  Zip_Code   Latitude   Longitude Alcohol_Service  \
# 0         Tamaulipas  Mexico       NaN  23.752304  -99.166913            None
# 1    San Luis Potosi  Mexico       NaN  22.141647 -100.992712            None
# 2            Morelos  Mexico   62000.0  18.922290  -99.234332            None
# 3         Tamaulipas  Mexico       NaN  23.752365  -99.165288            None
# 4         Tamaulipas  Mexico       NaN  23.752168  -99.165709            None
# ..               ...     ...       ...        ...         ...             ...
# 107  San Luis Potosi  Mexico   78290.0  22.141421 -101.013955            None
# 108          Morelos  Mexico       NaN  18.876011  -99.219890            None
# 109       Tamaulipas  Mexico       NaN  23.752982  -99.168434        Full Bar
# 110  San Luis Potosi  Mexico   78000.0  22.149709 -100.976093     Wine & Beer
# 111          Morelos  Mexico       NaN  18.921785  -99.235350     Wine & Beer
#
#     Smoking_Allowed   Price Franchise    Area Parking    Cuisine
# 0               Yes     Low        No    Open  Public   Regional
# 1                No     Low        No  Closed     Yes  Cafeteria
# 2                No     Low       Yes  Closed    None   American
# 3                No  Medium       Yes  Closed     Yes    Mexican
# 4                No     Low        No    Open  Public    Mexican
# ..              ...     ...       ...     ...     ...        ...
# 107              No  Medium       Yes  Closed     Yes  Fast Food
# 108              No     Low        No  Closed  Public  Cafeteria
# 109              No  Medium       Yes  Closed     Yes    Mexican
# 110        Bar Only  Medium        No    Open    None    Mexican
# 111              No  Medium        No  Closed    None    Italian
#
# [112 rows x 15 columns]

# %% [markdown]
# # Remove Unnecessary Columns

# %%
restaurant_df.columns
# Out:
# Index(['Restaurant_ID', 'Name', 'City', 'State', 'Country', 'Zip_Code',
#        'Latitude', 'Longitude', 'Alcohol_Service', 'Smoking_Allowed', 'Price',
#        'Franchise', 'Area', 'Parking', 'Cuisine'],
#       dtype='object')

# %%
restaurant_df.drop(['City', 'State', 'Country', 'Zip_Code',
       'Latitude', 'Longitude', 'Alcohol_Service', 'Smoking_Allowed', 'Price',
       'Franchise', 'Area', 'Parking'], axis=1, inplace=True)

# %%
restaurant_df
# Out:
#      Restaurant_ID                                Name    Cuisine
# 0           132560                  Puesto de Gorditas   Regional
# 1           132572                        Cafe Chaires  Cafeteria
# 2           132583                    McDonalds Centro   American
# 3           132584                  Gorditas Doña Tota    Mexican
# 4           132594  Tacos De Barbacoa Enfrente Del Tec    Mexican
# ..             ...                                 ...        ...
# 107         135086         McDonalds Parque Tangamanga  Fast Food
# 108         135088                   Cafeteria Cenidet  Cafeteria
# 109         135104                                Vips    Mexican
# 110         135106          El Rincón De San Francisco    Mexican
# 111         135109                           Paniroles    Italian
#
# [112 rows x 3 columns]

# %% [markdown]
# # Export CSV

# %%
restaurant_df.to_csv('restaurant_data.csv')

# %% [markdown]
# # Remove Columns from Ratings Dataframe

# %%
restaurant_ratings = pd.read_csv('ratings.csv')
restaurant_ratings
# Out:
#      Consumer_ID  Restaurant_ID  Overall_Rating  Food_Rating  Service_Rating
# 0          U1077         135085               2            2               2
# 1          U1077         135038               2            2               1
# 2          U1077         132825               2            2               2
# 3          U1077         135060               1            2               2
# 4          U1068         135104               1            1               2
# ...          ...            ...             ...          ...             ...
# 1156       U1043         132630               1            1               1
# 1157       U1011         132715               1            1               0
# 1158       U1068         132733               1            1               0
# 1159       U1068         132594               1            1               1
# 1160       U1068         132660               0            0               0
#
# [1161 rows x 5 columns]

# %%
restaurant_ratings.drop(['Food_Rating', 'Service_Rating'], axis=1, inplace=True)

# %%
restaurant_ratings
# Out:
#      Consumer_ID  Restaurant_ID  Overall_Rating
# 0          U1077         135085               2
# 1          U1077         135038               2
# 2          U1077         132825               2
# 3          U1077         135060               1
# 4          U1068         135104               1
# ...          ...            ...             ...
# 1156       U1043         132630               1
# 1157       U1011         132715               1
# 1158       U1068         132733               1
# 1159       U1068         132594               1
# 1160       U1068         132660               0
#
# [1161 rows x 3 columns]

# %%
restaurant_ratings.to_csv('restaurant_ratings.csv')
